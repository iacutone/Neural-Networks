# %%
import torch
from torch.autograd import Variable as V

# %%
x_data = V(torch.Tensor([[1.0], [2.0], [3.0]]))
y_data = V(torch.Tensor([[2.0], [4.0], [6.0]]))
           
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1, 1) # 1 in (from x value), 1 out
    
    def forward(self, x):
        y_hat = self.linear(x)
        return y_hat

# %%
model = Model()
criterion = torch.nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(500):
    y_hat = model(x_data) # forward pass
    
    loss = criterion(y_hat, y_data)
    print(epoch, loss.data[0])
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step() # update
# Out:
# 0 144.57952880859375
# 1 64.44525146484375
# 2 28.770566940307617
# 3 12.888041496276855
# 4 5.816440105438232
# 5 2.6672279834747314
# 6 1.264167070388794
# 7 0.638461172580719
# 8 0.35882654786109924
# 9 0.23326948285102844
# 10 0.17631837725639343
# 11 0.14992357790470123
# 12 0.1371467262506485
# 13 0.13044722378253937
# 14 0.12646736204624176
# 15 0.12371279299259186
# 16 0.12151758372783661
# 17 0.11958539485931396
# 18 0.11778408288955688
# 19 0.11605460196733475
# 20 0.11437038332223892
# 21 0.11271943151950836
# 22 0.11109618842601776
# 23 0.10949809849262238
# 24 0.10792383551597595
# 25 0.10637257248163223
# 26 0.1048436313867569
# 27 0.10333679616451263
# 28 0.101851686835289
# 29 0.10038790106773376
# 30 0.09894521534442902
# 31 0.09752316772937775
# 32 0.0961216613650322
# 33 0.09474025666713715
# 34 0.09337863326072693
# 35 0.0920366495847702
# 36 0.09071404486894608
# 37 0.08941012620925903
# 38 0.08812525123357773
# 39 0.08685868978500366
# 40 0.08561034500598907
# ...

# %%
tester_var = V(torch.Tensor([[4.0]]))
print("predict (after training)", model.forward(tester_var).data[0])
# Out:
# predict (after training)
#  7.9879
# [torch.FloatTensor of size 1]
